# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uRed
import logging

# %%
flipkart_url="https://www.flipkart.com/search?q="+"redami"

# %%
urlclient=uRed(flipkart_url)

# %%
flipkart_page=urlclient.read()

# %%
flipkart_html=bs(flipkart_page,'html.parser')

# %%
"https://www.flipkart.com/"+"/apple-iphone-12-pro-pacific-blue-128-gb/p/itm97c833296c221?pid=MOBFWBYZXYSCEEEH&amp;lid=LSTMOBFWBYZXYSCEEEHWV51IN&amp;marketplace=FLIPKART&amp;q=iphone12+pro&amp;store=tyy%2F4io&amp;srno=s_1_4&amp;otracker=AS_Query_OrganicAutoSuggest_3_8_na_na_na&amp;otracker1=AS_Query_OrganicAutoSuggest_3_8_na_na_na&amp;fm=organic&amp;iid=7a01742f-2e29-4467-ac77-5dd0cd6e86e5.MOBFWBYZXYSCEEEH.SEARCH&amp;ppt=hp&amp;ppn=homepage&amp;ssid=zsmlvpshs00000001705831968285&amp;qH=0409633344bf4d16"
# Out:
# 'https://www.flipkart.com//apple-iphone-12-pro-pacific-blue-128-gb/p/itm97c833296c221?pid=MOBFWBYZXYSCEEEH&amp;lid=LSTMOBFWBYZXYSCEEEHWV51IN&amp;marketplace=FLIPKART&amp;q=iphone12+pro&amp;store=tyy%2F4io&amp;srno=s_1_4&amp;otracker=AS_Query_OrganicAutoSuggest_3_8_na_na_na&amp;otracker1=AS_Query_OrganicAutoSuggest_3_8_na_na_na&amp;fm=organic&amp;iid=7a01742f-2e29-4467-ac77-5dd0cd6e86e5.MOBFWBYZXYSCEEEH.SEARCH&amp;ppt=hp&amp;ppn=homepage&amp;ssid=zsmlvpshs00000001705831968285&amp;qH=0409633344bf4d16'

# %%
flipkart_html()
# Out:
# [<html lang="en"><head><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css" rel="stylesheet"/><link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.615ed9.css" rel="stylesheet"/><meta content="text/html; charset=utf-8" http-equiv="Content-type"/><meta content="IE=Edge" http-equiv="X-UA-Compatible"/><meta content="102988293558" property="fb:page_id"/><meta content="658873552,624500995,100000233612389" property="fb:admins"/><link href="https:///www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/><link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/><meta content="website" property="og:type"/><meta content="Flipkart.com" name="og_site_name" property="og:site_name"/><link href="/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/><link href="/apple-touch-icon-72x72.png" rel=
# ...

# %%
bigbox=flipkart_html.findAll("div",{"class":"_1AtVbE col-12-12"})

# %%
len(bigbox)
# Out:
# 30

# %%
bigbox[3].div.div.div.a["href"]
# Out:
# '/redmi-12-pastel-blue-128-gb/p/itm9b1a6640faccd?pid=MOBGRMFKAHNTZPWE&lid=LSTMOBGRMFKAHNTZPWE1H5IWS&marketplace=FLIPKART&q=redami&store=tyy%2F4io&srno=s_1_2&otracker=search&fm=organic&iid=2e8e567b-5aaf-4ac3-91ba-a133ae983318.MOBGRMFKAHNTZPWE.SEARCH&ppt=None&ppn=None&ssid=kuzggjgg340000001705853296435&qH=467df3c2a02957f2'

# %%
del bigbox[0:3]

# %%
product_link="https://www.flipkart.com"+bigbox[3].div.div.div.a["href"]

# %%
product_req=requests.get(product_link)

# %%
product_link
# Out:
# 'https://www.flipkart.com/redmi-12-jade-black-128-gb/p/itmb7050ec01c09f?pid=MOBGRMFKTHKQSJEG&lid=LSTMOBGRMFKTHKQSJEGQK3FM2&marketplace=FLIPKART&q=redami&store=tyy%2F4io&srno=s_1_5&otracker=search&fm=organic&iid=2e8e567b-5aaf-4ac3-91ba-a133ae983318.MOBGRMFKTHKQSJEG.SEARCH&ppt=None&ppn=None&ssid=kuzggjgg340000001705853296435&qH=467df3c2a02957f2'

# %%
product_html=bs(product_req.text,"html.parser")

# %%
comment_box=product_html.findAll("div",{"class":"_16PBlm"})

# %%
len(comment_box)
# Out:
# 11

# %%
for i in comment_box:
    print(i.div.div.find_all("p","_2sc7ZR _2V5EHH")[0].text)
# Out:
# Pritam Chaudhury
# Shadik Hussain
# Udhab Das
# Prabhat Ranjan
# Sandis Girish
# Shahrukh  Pathan
# Rakesh Sing
# Sentu Majee
# Rahul kushwah
# Rajat kumar
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[228], line 2
#       1 for i in comment_box:
# ----> 2     print(i.div.div.find_all("p","_2sc7ZR _2V5EHH")[0].text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
comment_box[0].div.div.div.div.text

# %%
for i in comment_box:
    print(i.div.div.div.div.text)

# %%
comment_box[0].div.div.div.p.text
# Out:
# 'Just wow!'

# %%
for i in comment_box:
    print(i.div.div.div.p.text)
# Out:
# Just wow!
# Just wow!
# Must buy!
# Really Nice
# Terrific purchase
# Worth every penny
# Really Nice
# Mind-blowing purchase
# Fabulous!
# Terrific
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[230], line 2
#       1 for i in comment_box:
# ----> 2     print(i.div.div.div.p.text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
comment_box[0].div.div.find_all("div",{"class":""})[0].div.text
# Out:
# "The phone is too good. I prefer to buy this phone. Low Budget excellent phone. Large Display size and smooth task finishing.. And I'm reviewing this in two days. I have added some photos which are clicked on this phone.THANK YOU"

# %%
for i in comment_box:
    print(i.div.div.find_all("div",{"class":""})[0].div.text)
# Out:
# The phone is too good. I prefer to buy this phone. Low Budget excellent phone. Large Display size and smooth task finishing.. And I'm reviewing this in two days. I have added some photos which are clicked on this phone.THANK YOU
# Nice mobile 👌
# Very good a quality
# Best in the market in this price range 💗Loved it !!
# Best.... Value of money
# Good product 👌
# Nice 👍
# Very nice phone
# Good phone
# Nice Phone On This Price 🙂
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[232], line 2
#       1 for i in comment_box:
# ----> 2     print(i.div.div.find_all("div",{"class":""})[0].div.text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
for i in bigbox:
    print("https://www.flipkart.com"+i.div.div.div.a["href"])
# Out:
# https://www.flipkart.com/redmi-note-13-pro-5g-fusion-purple-256-gb/p/itmb1aa74d7307e2?pid=MOBGWFHFMH3FAA39&lid=LSTMOBGWFHFMH3FAA39MVQF4L&marketplace=FLIPKART&q=redami-note-12_5g&store=tyy%2F4io&srno=s_1_2&otracker=search&fm=organic&iid=7c17da85-682f-4eec-b1c2-a09816156667.MOBGWFHFMH3FAA39.SEARCH&ppt=None&ppn=None&ssid=qgojewcs000000001705852451967&qH=615ea29b7d9b4286
# https://www.flipkart.com/redmi-note-12-pro-5g-glacier-blue-128-gb/p/itm8fbee21008560?pid=MOBGH2UVZHHQGRRP&lid=LSTMOBGH2UVZHHQGRRPHJOZCG&marketplace=FLIPKART&q=redami-note-12_5g&store=tyy%2F4io&srno=s_1_3&otracker=search&fm=organic&iid=7c17da85-682f-4eec-b1c2-a09816156667.MOBGH2UVZHHQGRRP.SEARCH&ppt=None&ppn=None&ssid=qgojewcs000000001705852451967&qH=615ea29b7d9b4286
# ...
